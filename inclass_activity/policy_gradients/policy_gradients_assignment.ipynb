# %% [markdown]
# # Policy Gradients Implementation - Assignment
#
# This notebook implements key components from the Policy Gradients chapter.
#
# **Instructions:** Fill in the TODO sections to implement each function.
#
# Reference: https://rlhfbook.com/c/06-policy-gradients#implementation

# %%
import torch

# %% [markdown]
# ## 1. Probability Ratio Computation
#
# Computes the importance sampling ratio between new and old policy log probabilities.
#
# Formula: `ratio = exp(new_logps - old_logps) = π_θ(a|s) / π_θ_old(a|s)`

# %%
def compute_probability_ratio(new_logps: torch.Tensor, old_logps: torch.Tensor) -> torch.Tensor:
    """
    Compute the probability ratio between new and old policies.
    
    Args:
        new_logps: Log probabilities from the new policy, shape (batch_size, seq_len)
        old_logps: Log probabilities from the old policy, shape (batch_size, seq_len)
    
    Returns:
        ratio: Probability ratio π_θ/π_θ_old, shape (batch_size, seq_len)
    """
    # TODO: Implement probability ratio computation
    pass

# %% [markdown]
# ## 2. Basic Policy Gradient Loss
#
# The fundamental policy gradient loss: `pg_loss = -advantages * ratio`

# %%
def compute_policy_gradient_loss(advantages: torch.Tensor, ratio: torch.Tensor) -> torch.Tensor:
    """
    Compute the basic policy gradient loss.
    
    Args:
        advantages: Advantage values, shape (batch_size, seq_len)
        ratio: Probability ratio π_θ/π_θ_old, shape (batch_size, seq_len)
    
    Returns:
        pg_loss: Policy gradient loss (per token), shape (batch_size, seq_len)
    """
    # TODO: Implement policy gradient loss
    pass

# %% [markdown]
# ## 3. RLOO (Leave-One-Out) Advantages
#
# Computes advantages using leave-one-out baseline estimation.
#
# Formula: `A(s, a_k) = R(s, a_k) - (1/(K-1) * Σ_{i≠k} R(s, a_i))`

# %%
def compute_rloo_advantages(rewards: torch.Tensor, rloo_k: int) -> torch.Tensor:
    """
    Compute RLOO (leave-one-out) advantages.
    
    Args:
        rewards: Rewards for all samples, shape (N * rloo_k,) where N is number of prompts
        rloo_k: Number of samples per prompt
    
    Returns:
        advantages: RLOO advantages, shape (N * rloo_k,)
    """
    # TODO: Implement RLOO advantage computation
    # Hint: Reshape rewards to (N, rloo_k), compute baseline excluding each sample
    pass

# %% [markdown]
# ## 4. GRPO (Group Relative Policy Optimization) Advantages
#
# Computes advantages using group-wise reward normalization.
#
# Formula: `A_i = (r_i - mean(r_1:G)) / std(r_1:G)`

# %%
def compute_grpo_advantages(rewards: torch.Tensor, num_generations: int) -> torch.Tensor:
    """
    Compute GRPO advantages with group-wise normalization.
    
    Args:
        rewards: Rewards for all samples, shape (num_prompts * num_generations,)
        num_generations: Number of generations per prompt
    
    Returns:
        advantages: Normalized advantages, shape (num_prompts * num_generations,)
    """
    # TODO: Implement GRPO advantage computation
    # Hint: Reshape, compute mean and std per group, normalize
    # Add small epsilon (1e-4) to std for numerical stability
    pass

# %% [markdown]
# ## 5. Monte Carlo Returns with Discounting
#
# Computes discounted returns for value function training.
#
# Formula: `G_t = r_t + γ * G_{t+1}`

# %%
def compute_returns_monte_carlo(rewards: torch.Tensor, gamma: float, done_mask: torch.Tensor) -> torch.Tensor:
    """
    Compute Monte Carlo returns with discounting.
    
    Args:
        rewards: Rewards at each timestep, shape (batch_size, seq_len)
        gamma: Discount factor
        done_mask: Binary mask (1 at episode end, 0 otherwise), shape (batch_size, seq_len)
    
    Returns:
        returns: Discounted returns G_t, shape (batch_size, seq_len)
    """
    # TODO: Implement Monte Carlo return computation
    # Hint: Iterate backwards through time, accumulate discounted rewards
    # Reset accumulation when done_mask is 1
    pass

# %% [markdown]
# ## Testing Your Implementation
#
# After implementing all functions, import and test your code by running:

# %%
# Uncomment to run tests in notebook
# IMPORTANT: Remove this cell or comment out when submitting to Gradescope

# import test_policy_gradients
# test_policy_gradients.run_all_tests(
#     compute_probability_ratio,
#     compute_policy_gradient_loss,
#     compute_rloo_advantages,
#     compute_grpo_advantages,
#     compute_returns_monte_carlo
# )



# To test each function:

# import test_policy_gradients
# test_policy_gradients.test_compute_probability_ratio(compute_probability_ratio)
# test_policy_gradients.test_compute_policy_gradient_loss(compute_policy_gradient_loss)
# test_policy_gradients.test_compute_rloo_advantages(compute_rloo_advantages)
# test_policy_gradients.test_compute_grpo_advantages(compute_grpo_advantages)
# test_policy_gradients.test_compute_returns_monte_carlo(compute_returns_monte_carlo)

# %% [markdown]
# ## Summary
#
# This notebook covers 5 key policy gradient implementations:
#
# 1. **Probability Ratio**: Importance sampling ratio for policy updates
# 2. **Basic PG Loss**: Core policy gradient objective
# 3. **RLOO Advantages**: Leave-one-out baseline estimation
# 4. **GRPO Advantages**: Group-wise reward normalization
# 5. **Monte Carlo Returns**: Discounted return computation

# %% [markdown]
# ## Submission
#
# Submit this notebook file to Gradescope.
#
# IMPORTANT: Remove test cells (or comment out) when submitting to Gradescope
